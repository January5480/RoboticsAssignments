# %%
import torch
from torch import nn

# %%
def comp_conv2d(conv2d, X):
    X = X.reshape((1, 1) + X.shape)
    Y = conv2d(X)
    return Y.reshape(Y.shape[2:])

# %%
X = torch.rand(size=[8, 8])
X.shape
(1, 1) + X.shape
# Out:
# (1, 1, 8, 8)

# %%
X = torch.rand(size=[8, 8])
conv2d = nn.Conv2d(1, 1, kernel_size=3, padding=1)
comp_conv2d(conv2d, X)
# Out:
# tensor([[-0.0384, -0.1340, -0.3083, -0.2851, -0.0294, -0.4715, -0.3873, -0.1664],
#         [-0.0297, -0.0906,  0.3242, -0.2878, -0.2978,  0.0681,  0.1690, -0.0591],
#         [ 0.2736, -0.0695,  0.1314,  0.0059,  0.0319, -0.1786, -0.2287, -0.1270],
#         [ 0.0123, -0.0124, -0.0632, -0.2146,  0.0105,  0.1900,  0.0276, -0.0265],
#         [ 0.0774,  0.0905, -0.0915,  0.0986, -0.2873, -0.2551, -0.0166, -0.0698],
#         [ 0.1615,  0.1152, -0.2360, -0.1314, -0.2681,  0.0389, -0.1393, -0.1640],
#         [-0.1628, -0.1585, -0.2377, -0.0866, -0.0649, -0.2475, -0.0184, -0.0287],
#         [ 0.0484,  0.0913, -0.1385, -0.0769, -0.1362, -0.1495, -0.1729, -0.1923]],
#        grad_fn=<ReshapeAliasBackward0>)

# %%
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([8, 8])

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=(5, 3), padding=(2, 1))
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([8, 8])

# %% [markdown]
# 步幅

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=3, padding=1, stride=2)
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([4, 4])

# %%
conv2d = nn.Conv2d(1, 1, kernel_size=(3, 5), padding=(0, 1), stride=(3, 4))
comp_conv2d(conv2d, X).shape
# Out:
# torch.Size([2, 2])
